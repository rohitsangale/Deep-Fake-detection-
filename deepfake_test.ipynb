# %%
from keras.models import load_model
c=load_model("modeld.h5")
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
import numpy as np
import keras 
from keras import backend as K
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing import image 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.applications import imagenet_utils

# %%
def prepare_image(file):
    img_path=('ct/')
    img=image.load_img(img_path+file,target_size=(224,224))
    img_array=image.img_to_array(img)
    img_array_expanded_dims=np.expand_dims(img_array,axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='ct/chris.jpg',width=300,height=200)

# %%
preprocessed_image=prepare_image('chris.jpg')

# %%
predictions=c.predict(preprocessed_image)

# %%
predictions
# Out:
# array([[0.62400967, 0.3759904 ]], dtype=float32)

# %%
if predictions[0][0]>0.5:
  print("fake")
else:
  print("real")
# Out:
# fake

# %%
def make_prediction(file):
  img_path=('ct/')
  display(Image(filename=img_path+file,width=300,height=300))
  preprocessed_image=prepare_image(file)
  predictions=c.predict(preprocessed_image)
  if predictions[0][0]>0.5:
    print("fake")
  else:
    print("real")

# %%
make_prediction("srk1.jpg")
# Out:
# real

# %%
make_prediction("mrg.jpg")
# Out:
# fake

# %%
preprocessed_image=prepare_image('mrg.jpg')
predictions=c.predict(preprocessed_image)

# %%
predictions
# Out:
# [[0.6265158  0.37348416]]

# %%
make_prediction("jaq.jpg")
# Out:
# real

# %%
make_prediction("rav.jpg")
# Out:
# fake

# %%
make_prediction("margo.jpg")
# Out:
# real

# %%
make_prediction("snapchatt.jpg")
# Out:
# fake

# %%
make_prediction("ff.png")
# Out:
# real

# %%
preprocessed_image=prepare_image('ff.png')
predictions=c.predict(preprocessed_image)

# %%
predictions
# Out:
# array([[0.32819426, 0.6718057 ]], dtype=float32)

# %%
make_prediction("west.jpg")
# Out:
# real

# %%
make_prediction("pu.jpg")
# Out:
# fake

# %%
make_prediction("tomcrr.jpg")
# Out:
# real

# %%
preprocessed_image=prepare_image('tomcrr.jpg')
predictions=c.predict(preprocessed_image)
print(predictions)
# Out:
# [[0.4617867 0.5382133]]

# %%
make_prediction("tulr.jpg")
# Out:
# real

# %%
make_prediction("rohit.jpg")
# Out:
# real
